# %% [markdown]
# # Part I: Understanding the Problem and Data Exploration
# <img src="IMG/workflow.png">

# %% [markdown]
# ## Frame the problem
#
# Before looking at the data it is important to understand how does the company expect to use and benefit from this model? This first brainstorming helps to determine how to frame the problem, what algorithms to select and measure the performance of each one.

# %% [markdown]
# ## Make Assumptions
#
# It is good to make some assumptions on what possible outcomes we might expect from our analysis according to the available data. Therefore, by knowing the goal we should think which possible factors might affect the sales prediction outcome.

# %% [markdown]
# # Start Data Exploration (EDA)
# * browse and clean data
# * look univariate and multivariate statistics
# * isolate and investigate the statistics of groups
# * visualize interesting findings
# * prepare a small report on your findings (in a seperate notebook)

# %% [markdown]
# ## Getting Started

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings # Ignores any warning
warnings.filterwarnings("ignore")

#Important. for now, we only look at the available train data
train = pd.read_csv("DATA/Train.csv")

# %%
train.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
# 8           Frozen Foods   96.9726            OUT045
# 9           Frozen Foods  187.8214            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
# 6                       1987        High               Tier 3
# 7                       1985      Medium               Tier 3
# 8                       2002         NaN               Tier 2
# 9                       2007         NaN               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
# 5  Supermarket Type2           556.6088
# 6  Supermarket Type1           343.5528
# 7  Supermarket Type3          4022.7636
# 8  Supermarket Type1          1076.5986
# 9  Supermarket Type1          4710.5350

# %%
train.isnull().any()
# Out:
# Item_Identifier              False
# Item_Weight                   True
# Item_Fat_Content             False
# Item_Visibility              False
# Item_Type                    False
# Item_MRP                     False
# Outlet_Identifier            False
# Outlet_Establishment_Year    False
# Outlet_Size                   True
# Outlet_Location_Type         False
# Outlet_Type                  False
# Item_Outlet_Sales            False
# dtype: bool

# %%
train_nans = train.isnull()
train_nans = train_nans.any(axis=1)
train_nans
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
# 5       False
# 6       False
# 7        True
# 8        True
# 9        True
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18       True
# 19      False
# 20      False
# 21       True
# 22      False
# 23       True
# 24      False
# 25       True
# 26      False
# 27      False
# 28       True
# 29       True
#         ...
# 8493     True
# 8494     True
# 8495    False
# 8496     True
# 8497    False
# 8498    False
# 8499    False
# 8500     True
# 8501     True
# 8502     True
# 8503    False
# 8504     True
# 8505    False
# 8506    False
# 8507    False
# 8508     True
# 8509     True
# 8510    False
# 8511    False
# 8512    False
# 8513    False
# 8514     True
# 8515    False
# 8516    False
# 8517    False
# 8518    False
# 8519     True
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
# Erkenntnis: Es gibt nur nans in weigth und size --> nummerische Attribute --> mathematische Ansätze (median/mean) zur Ersetzung von nans möglich
# Idee: Korrelation zwischen weight und type rauszufinden und dann ggf. 
train.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
def fat_to_numeric(x):
    if (x == 'Low Fat') or (x == 'low fat') or (x == 'LF'):
        return 0
    if (x == 'Regular') or (x == 'reg'):
        return 1
    
def type_to_numeric(x):
    if (x == 'Dairy'):
        return 0
    if (x == 'Soft Drinks'):
        return 1
    if (x == 'Meat'):
        return 2
    if (x == 'Fruits and Vegetables'):
        return 3
    if (x == 'Household'):
        return 4
    if (x == 'Baking Goods'):
        return 5
    if (x == 'Snack Foods'):
        return 6
    if (x == 'Frozen Foods'):
        return 7
    if (x == 'Breakfast'):
        return 8
    if (x == 'Health and Hygiene'):
        return 9
    if (x == 'Hard Drinks'):
        return 10
    if (x == 'Canned'):
        return 11
    if (x == 'Breads'):
        return 12
    if (x == 'Starchy Foods'):
        return 13
    if (x == 'Others'):
        return 14
    if (x == 'Seafood'):
        return 15
    
def size_to_numeric(x):
    if (x == 'Small'):
        return 0
    if (x == 'Medium'):
        return 1
    if (x == 'High'):
        return 2
    return 3
    
def loc_type_to_numeric(x):
    if (x=='Tier 1'):
        return 0
    if (x=='Tier 2'):
        return 1
    if (x=='Tier 3'):
        return 2

def type_to_numeric(x):
    if (x=='Supermarket Type1'):
        return 0
    if (x=='Supermarket Type2'):
        return 1
    if (x=='Supermarket Type3'):
        return 2
    if (x=='Grocery Store'):
        return 3

# %%
train['Item_Type_n'] = train['Item_Type'].apply(type_to_numeric)

# %%
train.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
train['Item_Fat_Content_n'] = train['Item_Fat_Content'].apply(fat_to_numeric)

# %%
train.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
# Item_Fat_Content_n           -0.023238         0.047314  0.006063
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales  \
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000
# Item_Fat_Content_n                          0.003151           0.018719
#
#                            Item_Fat_Content_n
# Item_Weight                         -0.023238
# Item_Visibility                      0.047314
# Item_MRP                             0.006063
# Outlet_Establishment_Year            0.003151
# Item_Outlet_Sales                    0.018719
# Item_Fat_Content_n                   1.000000

# %%
types = train.groupby('Item_Type')# ["Item_Wight"]
for grp, data in types:
    print(grp+ ':')
    print('mean: ' + str(data['Item_Weight'].mean()))
    print('median: ' + str(data['Item_Weight'].median()))
    print( ' ')
# Out:
# Baking Goods:
# mean: 12.277108208955255
# median: 11.65
#
# Breads:
# mean: 11.3469362745098
# median: 10.6
#
# Breakfast:
# mean: 12.768202247191002
# median: 10.695
#
# Canned:
# mean: 12.305705009276451
# median: 12.15
#
# Dairy:
# mean: 13.42606890459367
# median: 13.35
#
# Frozen Foods:
# mean: 12.867061281337076
# median: 12.85
#
# Fruits and Vegetables:
# mean: 13.224769381746881
# median: 13.1
#
# Hard Drinks:
# mean: 11.400327868852452
# median: 10.1
#
# Health and Hygiene:
# mean: 13.142313953488392
# median: 12.15
#
# Household:
# mean: 13.384736495388726
# median: 13.15
#
# Meat:
# mean: 12.81734421364986
# median: 12.35
#
# Others:
# mean: 13.853284671532842
# median: 14.5
#
# Seafood:
# mean: 12.5528431372549
# median: 11.65
#
# Snack Foods:
# mean: 12.987879554655919
# median: 13.15
#
# Soft Drinks:
# mean: 11.847459893048129
# median: 11.8
#
# Starchy Foods:
# mean: 13.690730769230765
# median: 13.175

# %%
# --> meadian und mean liegen relativ nahe beisammen und zwar bei allen Typen --> keine einseitigen Ausreiser --> für nans in weght median/ mean benutzen

# %%
train['Item_Weight'].fillna(train['Item_Weight'].mean() ,inplace=True)

# %%
# gleiches noch für outletsize
types = train.groupby('Item_Type')# ["Item_Wight"]
for grp, data in types:
    print(grp+ ':')
    print('mean: ' + str(data['Item_Weight'].mean()))
    print('median: ' + str(data['Item_Weight'].median()))
    print( ' ')
# Out:
# Baking Goods:
# mean: 12.377447933060623
# median: 12.857645184136183
#
# Breads:
# mean: 11.629818022527507
# median: 12.8
#
# Breakfast:
# mean: 12.785277716971441
# median: 12.857645184136183
#
# Canned:
# mean: 12.399254191456087
# median: 12.857645184136183
#
# Dairy:
# mean: 13.329386864163975
# median: 12.857645184136183
#
# Frozen Foods:
# mean: 12.865543265666867
# median: 12.857645184136183
#
# Fruits and Vegetables:
# mean: 13.161297422257393
# median: 12.857645184136183
#
# Hard Drinks:
# mean: 11.6114345827487
# median: 11.225000000000001
#
# Health and Hygiene:
# mean: 13.093044358792845
# median: 12.857645184136183
#
# Household:
# mean: 13.297274090994096
# median: 12.857645184136183
#
# Meat:
# mean: 12.825688885185887
# median: 12.857645184136183
#
# Others:
# mean: 13.664761218297972
# median: 12.857645184136183
#
# Seafood:
# mean: 12.614756053027666
# median: 12.728822592068092
#
# Snack Foods:
# mean: 12.964871482530803
# median: 12.857645184136183
#
# Soft Drinks:
# mean: 12.008635523761084
# median: 12.857645184136183
#
# Starchy Foods:
# mean: 13.58940954942196
# median: 12.857645184136183

# %%
train['Outlet_Size_n'] = train['Outlet_Size'].apply(size_to_numeric)

# %%
train['Outlet_Location_Type_n'] = train['Outlet_Location_Type'].apply(loc_type_to_numeric)

# %%
train['Outlet_Type_n'] = train['Outlet_Type'].apply(type_to_numeric)

# %%
train['Outlet_Location_Type_n'] = train['Outlet_Location_Type'].apply(loc_type_to_numeric)

# %%
train.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.012049  0.024756
# Item_Visibility              -0.012049         1.000000 -0.001315
# Item_MRP                      0.024756        -0.001315  1.000000
# Outlet_Establishment_Year    -0.008301        -0.074834  0.005020
# Item_Outlet_Sales             0.011550        -0.128625  0.567574
# Item_Fat_Content_n           -0.021157         0.047314  0.006063
# Outlet_Size_n                -0.005356         0.003108 -0.008320
# Outlet_Location_Type_n        0.004088        -0.028099  0.000232
# Outlet_Type_n                 0.002725         0.223308 -0.006671
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales  \
# Item_Weight                                -0.008301           0.011550
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000
# Item_Fat_Content_n                          0.003151           0.018719
# Outlet_Size_n                               0.199485          -0.057464
# Outlet_Location_Type_n                     -0.089216           0.089367
# Outlet_Type_n                              -0.433070          -0.209854
#
#                            Item_Fat_Content_n  Outlet_Size_n  \
# Item_Weight                         -0.021157      -0.005356
# Item_Visibility                      0.047314       0.003108
# Item_MRP                             0.006063      -0.008320
# Outlet_Establishment_Year            0.003151       0.199485
# Item_Outlet_Sales                    0.018719      -0.057464
# Item_Fat_Content_n                   1.000000      -0.000517
# Outlet_Size_n                       -0.000517       1.000000
# Outlet_Location_Type_n              -0.001598       0.385597
# Outlet_Type_n                       -0.001967      -0.059041
#
#                            Outlet_Location_Type_n  Outlet_Type_n
# Item_Weight                              0.004088       0.002725
# Item_Visibility                         -0.028099       0.223308
# Item_MRP                                 0.000232      -0.006671
# Outlet_Establishment_Year               -0.089216      -0.433070
# Item_Outlet_Sales                        0.089367      -0.209854
# Item_Fat_Content_n                      -0.001598      -0.001967
# Outlet_Size_n                            0.385597      -0.059041
# Outlet_Location_Type_n                   1.000000       0.290939
# Outlet_Type_n                            0.290939       1.000000

# %%
# ==> Korrelation zwischen Size und Type angenommen
sizes = train.groupby(['Outlet_Type', 'Outlet_Size']).size()
sizes
# Out:
# Outlet_Type        Outlet_Size
# Grocery Store      Small           528
# Supermarket Type1  High            932
#                    Medium          930
#                    Small          1860
# Supermarket Type2  Medium          928
# Supermarket Type3  Medium          935
# dtype: int64

# %%
train.groupby('Outlet_Type').get_group('Grocery Store')['Outlet_Size'].count()
# Out:
# 528

# %%
# == > gruppierung hat funktioniert

# %%
for index, row in train.iterrows():
    if (row['Outlet_Size_n']== 3):
        if (row['Outlet_Type'] == 'Grocery Store') or (row['Outlet_Type'] == 'Supermarket Type1'):
            train.at[index, 'Outlet_Size'] = 'Small'
        if (row['Outlet_Type'] == 'Supermarket Type2') or (row['Outlet_Type'] == 'Supermarket Type3'):
            train.at[index, 'Outlet_Size'] = 'Medium'

# %%
train.isnull().any()
# Out:
# Item_Identifier              False
# Item_Weight                  False
# Item_Fat_Content             False
# Item_Visibility              False
# Item_Type                    False
# Item_MRP                     False
# Outlet_Identifier            False
# Outlet_Establishment_Year    False
# Outlet_Size                  False
# Outlet_Location_Type         False
# Outlet_Type                  False
# Item_Outlet_Sales            False
# Item_Type_n                   True
# Item_Fat_Content_n           False
# Outlet_Size_n                False
# Outlet_Location_Type_n       False
# Outlet_Type_n                False
# dtype: bool

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings # Ignores any warning    

def fat_to_numeric(x):
    if (x == 'Low Fat') or (x == 'low fat') or (x == 'LF'):
        return 0
    if (x == 'Regular') or (x == 'reg'):
        return 1
    
def type_to_numeric(x):
    if (x == 'Dairy'):
        return 0
    if (x == 'Soft Drinks'):
        return 1
    if (x == 'Meat'):
        return 2
    if (x == 'Fruits and Vegetables'):
        return 3
    if (x == 'Household'):
        return 4
    if (x == 'Baking Goods'):
        return 5
    if (x == 'Snack Foods'):
        return 6
    if (x == 'Frozen Foods'):
        return 7
    if (x == 'Breakfast'):
        return 8
    if (x == 'Health and Hygiene'):
        return 9
    if (x == 'Hard Drinks'):
        return 10
    if (x == 'Canned'):
        return 11
    if (x == 'Breads'):
        return 12
    if (x == 'Starchy Foods'):
        return 13
    if (x == 'Others'):
        return 14
    if (x == 'Seafood'):
        return 15
    
def size_to_numeric(x):
    if (x == 'Small'):
        return 0
    if (x == 'Medium'):
        return 1
    if (x == 'High'):
        return 2
    return 3
    
def loc_type_to_numeric(x):
    if (x=='Tier 1'):
        return 0
    if (x=='Tier 2'):
        return 1
    if (x=='Tier 3'):
        return 2

def type_to_numeric(x):
    if (x=='Supermarket Type1'):
        return 0
    if (x=='Supermarket Type2'):
        return 1
    if (x=='Supermarket Type3'):
        return 2
    if (x=='Grocery Store'):
        return 3

def proc_data(path):
    df = pd.read_csv(path)
    df['Item_Type_n'] = df['Item_Type'].apply(type_to_numeric)
    df['Item_Fat_Content_n'] = df['Item_Fat_Content'].apply(fat_to_numeric)
    
    df['Item_Weight'].fillna(df['Item_Weight'].mean() ,inplace=True)
    
    df['Outlet_Size_n'] = df['Outlet_Size'].apply(size_to_numeric)
    
    df['Outlet_Location_Type_n'] = df['Outlet_Location_Type'].apply(loc_type_to_numeric)
    
    df['Outlet_Type_n'] = df['Outlet_Type'].apply(type_to_numeric)
    
    df['Outlet_Location_Type_n'] = df['Outlet_Location_Type'].apply(loc_type_to_numeric) 
    
    for index, row in df.iterrows():
        if (row['Outlet_Size_n']== 3):
            if (row['Outlet_Type'] == 'Grocery Store') or (row['Outlet_Type'] == 'Supermarket Type1'):
                df.at[index, 'Outlet_Size'] = 'Small'
            if (row['Outlet_Type'] == 'Supermarket Type2') or (row['Outlet_Type'] == 'Supermarket Type3'):
                df.at[index, 'Outlet_Size'] = 'Medium'
    return df

# %%
df = proc_data("DATA/Train.csv")

# %%
df.isnull().any()
# Out:
# Item_Identifier              False
# Item_Weight                  False
# Item_Fat_Content             False
# Item_Visibility              False
# Item_Type                    False
# Item_MRP                     False
# Outlet_Identifier            False
# Outlet_Establishment_Year    False
# Outlet_Size                  False
# Outlet_Location_Type         False
# Outlet_Type                  False
# Item_Outlet_Sales            False
# Item_Type_n                   True
# Item_Fat_Content_n           False
# Outlet_Size_n                False
# Outlet_Location_Type_n       False
# Outlet_Type_n                False
# dtype: bool

# %%
import data_prep

# %%
df = data_prep.proc_data("DATA/Train.csv")

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000          Low Fat         0.016047
# 1              DRC01     5.920000          Regular         0.019278
# 2              FDN15    17.500000          Low Fat         0.016760
# 3              FDX07    19.200000          Regular         0.000000
# 4              NCD19     8.930000          Low Fat         0.000000
# 5              FDP36    10.395000          Regular         0.000000
# 6              FDO10    13.650000          Regular         0.012741
# 7              FDP10    12.857645          Low Fat         0.127470
# 8              FDH17    16.200000          Regular         0.016687
# 9              FDU28    19.200000          Regular         0.094450
# 10             FDY07    11.800000          Low Fat         0.000000
# 11             FDA03    18.500000          Regular         0.045464
# 12             FDX32    15.100000          Regular         0.100014
# 13             FDS46    17.600000          Regular         0.047257
# 14             FDF32    16.350000          Low Fat         0.068024
# 15             FDP49     9.000000          Regular         0.069089
# 16             NCB42    11.800000          Low Fat         0.008596
# 17             FDP49     9.000000          Regular         0.069196
# 18             DRI11    12.857645          Low Fat         0.034238
# 19             FDU02    13.350000          Low Fat         0.102492
# 20             FDN22    18.850000          Regular         0.138190
# 21             FDW12    12.857645          Regular         0.035400
# 22             NCB30    14.600000          Low Fat         0.025698
# 23             FDC37    12.857645          Low Fat         0.057557
# 24             FDR28    13.850000          Regular         0.025896
# 25             NCD06    13.000000          Low Fat         0.099887
# 26             FDV10     7.645000          Regular         0.066693
# 27             DRJ59    11.650000          low fat         0.019356
# 28             FDE51     5.925000          Regular         0.161467
# 29             FDC14    12.857645          Regular         0.072222
# ...              ...          ...              ...              ...
# 8493           FDP21     7.420000          Regular         0.025886
# 8494           NCI54    15.200000          Low Fat         0.000000
# 8495           FDE22     9.695000          Low Fat         0.029567
# 8496           FDJ57     7.420000          Regular         0.021696
# 8497           FDT08    13.650000          Low Fat         0.049209
# 8498           NCP54    15.350000          Low Fat         0.035293
# 8499           NCK53    11.600000          Low Fat         0.037574
# 8500           NCQ42    20.350000          Low Fat         0.000000
# 8501           FDW21     5.340000          Regular         0.005998
# 8502           NCH43     8.420000          Low Fat         0.070712
# 8503           FDQ44    20.500000          Low Fat         0.036133
# 8504           NCN18    12.857645          Low Fat         0.124111
# 8505           FDB46    10.500000          Regular         0.094146
# 8506           DRF37    17.250000          Low Fat         0.084676
# 8507           FDN28     5.880000          Regular         0.030242
# 8508           FDW31    11.350000          Regular         0.043246
# 8509           FDG45     8.100000          Low Fat         0.214306
# 8510           FDN58    13.800000          Regular         0.056862
# 8511           FDF05    17.500000          Low Fat         0.026980
# 8512           FDR26    20.700000          Low Fat         0.042801
# 8513           FDH31    12.000000          Regular         0.020407
# 8514           FDA01    15.000000          Regular         0.054489
# 8515           FDH24    20.700000          Low Fat         0.021518
# 8516           NCJ19    18.600000          Low Fat         0.118661
# 8517           FDF53    20.750000              reg         0.083607
# 8518           FDF22     6.865000          Low Fat         0.056783
# 8519           FDS36     8.380000          Regular         0.046982
# 8520           NCJ29    10.600000          Low Fat         0.035186
# 8521           FDN46     7.210000          Regular         0.145221
# 8522           DRG01    14.800000          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# 5              Baking Goods   51.4008            OUT018
# 6               Snack Foods   57.6588            OUT013
# 7               Snack Foods  107.7622            OUT027
# 8              Frozen Foods   96.9726            OUT045
# 9              Frozen Foods  187.8214            OUT017
# 10    Fruits and Vegetables   45.5402            OUT049
# 11                    Dairy  144.1102            OUT046
# 12    Fruits and Vegetables  145.4786            OUT049
# 13              Snack Foods  119.6782            OUT046
# 14    Fruits and Vegetables  196.4426            OUT013
# 15                Breakfast   56.3614            OUT046
# 16       Health and Hygiene  115.3492            OUT018
# 17                Breakfast   54.3614            OUT049
# 18              Hard Drinks  113.2834            OUT027
# 19                    Dairy  230.5352            OUT035
# 20              Snack Foods  250.8724            OUT013
# 21             Baking Goods  144.5444            OUT027
# 22                Household  196.5084            OUT035
# 23             Baking Goods  107.6938            OUT019
# 24             Frozen Foods  165.0210            OUT046
# 25                Household   45.9060            OUT017
# 26              Snack Foods   42.3112            OUT035
# 27              Hard Drinks   39.1164            OUT013
# 28                    Dairy   45.5086            OUT010
# 29                   Canned   43.6454            OUT019
# ...                     ...       ...               ...
# 8493            Snack Foods  189.1872            OUT017
# 8494              Household  110.4912            OUT017
# 8495            Snack Foods  160.4920            OUT035
# 8496                Seafood  185.3582            OUT017
# 8497  Fruits and Vegetables  150.0050            OUT035
# 8498              Household  124.5730            OUT018
# 8499     Health and Hygiene  100.0042            OUT035
# 8500              Household  125.1678            OUT017
# 8501            Snack Foods  100.4358            OUT017
# 8502              Household  216.4192            OUT045
# 8503  Fruits and Vegetables  120.1756            OUT035
# 8504              Household  111.7544            OUT027
# 8505            Snack Foods  210.8244            OUT018
# 8506            Soft Drinks  263.1910            OUT018
# 8507           Frozen Foods  101.7990            OUT035
# 8508  Fruits and Vegetables  199.4742            OUT045
# 8509  Fruits and Vegetables  213.9902            OUT010
# 8510            Snack Foods  231.5984            OUT035
# 8511           Frozen Foods  262.5910            OUT018
# 8512                  Dairy  178.3028            OUT013
# 8513                   Meat   99.9042            OUT035
# 8514                 Canned   57.5904            OUT045
# 8515           Baking Goods  157.5288            OUT018
# 8516                 Others   58.7588            OUT018
# 8517           Frozen Foods  178.8318            OUT046
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998       Small               Tier 3
# 4                          1987        High               Tier 3
# 5                          2009      Medium               Tier 3
# 6                          1987        High               Tier 3
# 7                          1985      Medium               Tier 3
# 8                          2002       Small               Tier 2
# 9                          2007       Small               Tier 2
# 10                         1999      Medium               Tier 1
# 11                         1997       Small               Tier 1
# 12                         1999      Medium               Tier 1
# 13                         1997       Small               Tier 1
# 14                         1987        High               Tier 3
# 15                         1997       Small               Tier 1
# 16                         2009      Medium               Tier 3
# 17                         1999      Medium               Tier 1
# 18                         1985      Medium               Tier 3
# 19                         2004       Small               Tier 2
# 20                         1987        High               Tier 3
# 21                         1985      Medium               Tier 3
# 22                         2004       Small               Tier 2
# 23                         1985       Small               Tier 1
# 24                         1997       Small               Tier 1
# 25                         2007       Small               Tier 2
# 26                         2004       Small               Tier 2
# 27                         1987        High               Tier 3
# 28                         1998       Small               Tier 3
# 29                         1985       Small               Tier 1
# ...                         ...         ...                  ...
# 8493                       2007       Small               Tier 2
# 8494                       2007       Small               Tier 2
# 8495                       2004       Small               Tier 2
# 8496                       2007       Small               Tier 2
# 8497                       2004       Small               Tier 2
# 8498                       2009      Medium               Tier 3
# 8499                       2004       Small               Tier 2
# 8500                       2007       Small               Tier 2
# 8501                       2007       Small               Tier 2
# 8502                       2002       Small               Tier 2
# 8503                       2004       Small               Tier 2
# 8504                       1985      Medium               Tier 3
# 8505                       2009      Medium               Tier 3
# 8506                       2009      Medium               Tier 3
# 8507                       2004       Small               Tier 2
# 8508                       2002       Small               Tier 2
# 8509                       1998       Small               Tier 3
# 8510                       2004       Small               Tier 2
# 8511                       2009      Medium               Tier 3
# 8512                       1987        High               Tier 3
# 8513                       2004       Small               Tier 2
# 8514                       2002       Small               Tier 2
# 8515                       2009      Medium               Tier 3
# 8516                       2009      Medium               Tier 3
# 8517                       1997       Small               Tier 1
# 8518                       1987        High               Tier 3
# 8519                       2002       Small               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales Item_Type_n  Item_Fat_Content_n  \
# 0     Supermarket Type1          3735.1380        None                   0
# 1     Supermarket Type2           443.4228        None                   1
# 2     Supermarket Type1          2097.2700        None                   0
# 3         Grocery Store           732.3800        None                   1
# 4     Supermarket Type1           994.7052        None                   0
# 5     Supermarket Type2           556.6088        None                   1
# 6     Supermarket Type1           343.5528        None                   1
# 7     Supermarket Type3          4022.7636        None                   0
# 8     Supermarket Type1          1076.5986        None                   1
# 9     Supermarket Type1          4710.5350        None                   1
# 10    Supermarket Type1          1516.0266        None                   0
# 11    Supermarket Type1          2187.1530        None                   1
# 12    Supermarket Type1          1589.2646        None                   1
# 13    Supermarket Type1          2145.2076        None                   1
# 14    Supermarket Type1          1977.4260        None                   0
# 15    Supermarket Type1          1547.3192        None                   1
# 16    Supermarket Type2          1621.8888        None                   0
# 17    Supermarket Type1           718.3982        None                   1
# 18    Supermarket Type3          2303.6680        None                   0
# 19    Supermarket Type1          2748.4224        None                   0
# 20    Supermarket Type1          3775.0860        None                   1
# 21    Supermarket Type3          4064.0432        None                   1
# 22    Supermarket Type1          1587.2672        None                   0
# 23        Grocery Store           214.3876        None                   0
# 24    Supermarket Type1          4078.0250        None                   1
# 25    Supermarket Type1           838.9080        None                   0
# 26    Supermarket Type1          1065.2800        None                   1
# 27    Supermarket Type1           308.9312        None                   0
# 28        Grocery Store           178.4344        None                   1
# 29        Grocery Store           125.8362        None                   1
# ...                 ...                ...         ...                 ...
# 8493  Supermarket Type1          4727.1800        None                   1
# 8494  Supermarket Type1          1637.8680        None                   0
# 8495  Supermarket Type1          4314.3840        None                   0
# 8496  Supermarket Type1          3715.1640        None                   1
# 8497  Supermarket Type1          2247.0750        None                   0
# 8498  Supermarket Type2          1601.2490        None                   0
# 8499  Supermarket Type1          2976.1260        None                   0
# 8500  Supermarket Type1          1907.5170        None                   0
# 8501  Supermarket Type1          1508.0370        None                   1
# 8502  Supermarket Type1          3020.0688        None                   0
# 8503  Supermarket Type1          3392.9168        None                   0
# 8504  Supermarket Type3          4138.6128        None                   0
# 8505  Supermarket Type2          2117.2440        None                   1
# 8506  Supermarket Type2          3944.8650        None                   0
# 8507  Supermarket Type1           515.9950        None                   1
# 8508  Supermarket Type1          2587.9646        None                   1
# 8509      Grocery Store           424.7804        None                   0
# 8510  Supermarket Type1          7182.6504        None                   1
# 8511  Supermarket Type2          4207.8560        None                   0
# 8512  Supermarket Type1          2479.4392        None                   0
# 8513  Supermarket Type1           595.2252        None                   1
# 8514  Supermarket Type1           468.7232        None                   1
# 8515  Supermarket Type2          1571.2880        None                   0
# 8516  Supermarket Type2           858.8820        None                   0
# 8517  Supermarket Type1          3608.6360        None                   1
# 8518  Supermarket Type1          2778.3834        None                   0
# 8519  Supermarket Type1           549.2850        None                   1
# 8520  Supermarket Type1          1193.1136        None                   0
# 8521  Supermarket Type2          1845.5976        None                   1
# 8522  Supermarket Type1           765.6700        None                   0
#
#       Outlet_Size_n  Outlet_Location_Type_n  Outlet_Type_n
# 0                 1                       0              0
# 1                 1                       2              1
# 2                 1                       0              0
# 3                 3                       2              3
# 4                 2                       2              0
# 5                 1                       2              1
# 6                 2                       2              0
# 7                 1                       2              2
# 8                 3                       1              0
# 9                 3                       1              0
# 10                1                       0              0
# 11                0                       0              0
# 12                1                       0              0
# 13                0                       0              0
# 14                2                       2              0
# 15                0                       0              0
# 16                1                       2              1
# 17                1                       0              0
# 18                1                       2              2
# 19                0                       1              0
# 20                2                       2              0
# 21                1                       2              2
# 22                0                       1              0
# 23                0                       0              3
# 24                0                       0              0
# 25                3                       1              0
# 26                0                       1              0
# 27                2                       2              0
# 28                3                       2              3
# 29                0                       0              3
# ...             ...                     ...            ...
# 8493              3                       1              0
# 8494              3                       1              0
# 8495              0                       1              0
# 8496              3                       1              0
# 8497              0                       1              0
# 8498              1                       2              1
# 8499              0                       1              0
# 8500              3                       1              0
# 8501              3                       1              0
# 8502              3                       1              0
# 8503              0                       1              0
# 8504              1                       2              2
# 8505              1                       2              1
# 8506              1                       2              1
# 8507              0                       1              0
# 8508              3                       1              0
# 8509              3                       2              3
# 8510              0                       1              0
# 8511              1                       2              1
# 8512              2                       2              0
# 8513              0                       1              0
# 8514              3                       1              0
# 8515              1                       2              1
# 8516              1                       2              1
# 8517              0                       0              0
# 8518              2                       2              0
# 8519              3                       1              0
# 8520              0                       1              0
# 8521              1                       2              1
# 8522              0                       0              0
#
# [8523 rows x 17 columns]
